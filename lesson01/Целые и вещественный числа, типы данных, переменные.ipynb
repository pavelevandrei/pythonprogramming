# %%
print("Hello World!")

# %%
2+9

# %% [markdown]
# 3-4

# %%
3-4

# %%
9348489534895348559 * 12348742374742342384894242304

# %%
115442088859397522422516218126403729550283239936 * 8834257435734853450394503450343450345

# %%
1019845131902896249400770248034789830925874976813366749788209680355261252803736977920 **

# %%
1019845131902896249400770248034789830925874976813366749788209680355261252803736977920**100
# Out:
# ...

# %%
11111 * 1111111

# %%
10 // 3

# %%
10 / 3

# %%
10 % 3

# %%
42/(4+2*(-2))

# %%
2 ** 5

# %%
2014 ** 14

# %%
2014 ** 143

# %%
2014 ** 14455

# %%
-(52)

# %%
+(-47)

# %%
+-+-+(45)

# %%
+-+-7

# %%
+-*8

# %%
print('Kek')
1+2
-*8

# %%
6 // 0

# %%
0.5 + 0.3

# %%
0.5*0.3

# %%
5 / 2

# %%
5 // 2

# %%
0.3+0.3+0.3

# %%
0.3+0.3

# %%
9 ** 0.5

# %%
5e-1

# %%
12e-10

# %%
2014.0 ** 14

# %%
2014 ** 14

# %%
7/3

# %%
7//3

# %%
float(5)

# %%
int(132283.565349)

# %%
int(2.99)

# %%
int(-1.6)

# %%
int(-2)

# %%
int(0.1)

# %%
int(-0.9)

# %%
9**19 - int(float(9**19))

# %%
9**19 - int(float(9**19))

# %%
9**19

# %%
float(9**19)

# %%
int(float(9**19))

# %%
9**16

# %%
float(9**16)

# %%
int(float(9**16))

# %%
type(76)

# %%
type('str')

# %%
type(True)

# %%
type(7.23)

# %%
type(int(7.23))

# %%
type(int(float(2)))

# %%
a=2

# %%
b=3

# %%
print(a+b)

# %%
a=6

# %%
print(a+b)

# %%
b=b+2

# %%
print(b)

# %%
print(c)

# %%
a=2
type(a)

# %%
a='abc'
type(a)

# %%
a=foo()
type

# %%
input()

# %%
name = input('Введите своё имя:')

# %%
sx

# %%
name = input('Введите своё имя:')
